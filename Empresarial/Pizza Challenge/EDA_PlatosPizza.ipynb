# %% [markdown]
# #EDA Plato's Pizza
#
# Análisis realizado con Pandas Profiling (ydata-profiling)

# %%
# libreriras
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
# permiso para importar data del drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# importar y asignar data a un df
df = pd.read_excel("/content/gdrive/MyDrive/3.Pizza+Place+Sales/Muestra.xlsx")

# %%
# ver el tipo y cantidad de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  500 non-null    int64
#  1   order_id          500 non-null    int64
#  2   pizza_id          500 non-null    object
#  3   quantity          500 non-null    int64
#  4   date              500 non-null    datetime64[ns]
#  5   time              500 non-null    datetime64[ns]
#  6   size              500 non-null    object
#  7   price             500 non-null    float64
#  8   name              500 non-null    object
#  9   category          500 non-null    object
#  10  ingredients       500 non-null    object
#  11  total_order       500 non-null    float64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(5)
# memory usage: 47.0+ KB

# %%
# estadistica descriptiva-cuantitativa
df.describe().round()
# Out:
#        order_details_id  order_id  quantity                           date  \
# count             500.0     500.0     500.0                            500
# mean            23870.0   10508.0       1.0  2015-06-26 05:02:24.000000256
# min                28.0      11.0       1.0            2015-01-01 00:00:00
# 25%             11266.0    4946.0       1.0            2015-03-24 18:00:00
# 50%             23588.0   10374.0       1.0            2015-06-23 12:00:00
# 75%             36511.0   16118.0       1.0            2015-09-29 00:00:00
# max             48302.0   21220.0       2.0            2015-12-29 00:00:00
# std             14040.0    6182.0       0.0                            NaN
#
#                                 time  price  total_order
# count                            500  500.0        500.0
# mean   2022-11-11 16:13:41.705999872   17.0         17.0
# min              2022-11-11 11:16:44   10.0         10.0
# 25%              2022-11-11 13:10:36   13.0         13.0
# ...

# %%
# estadistica descriptiva-cuantitativa y cualitativa
df.describe(include='all')
# Out:
#         order_details_id      order_id    pizza_id   quantity  \
# count         500.000000    500.000000         500  500.00000
# unique               NaN           NaN          90        NaN
# top                  NaN           NaN  thai_ckn_l        NaN
# freq                 NaN           NaN          22        NaN
# mean        23869.950000  10508.184000         NaN    1.02200
# min            28.000000     11.000000         NaN    1.00000
# 25%         11265.500000   4946.000000         NaN    1.00000
# 50%         23588.000000  10373.500000         NaN    1.00000
# 75%         36510.750000  16118.000000         NaN    1.00000
# max         48302.000000  21220.000000         NaN    2.00000
# std         14039.866992   6182.382128         NaN    0.14683
#
#                                  date                           time size  \
# count                             500                            500  500
# ...

# %%
# libreria para el reporte
# !pip install ydata-profiling
import ydata_profiling
from ydata_profiling import ProfileReport

# %%
# generar reporte
df = pd.read_excel("/content/gdrive/MyDrive/3.Pizza+Place+Sales/Muestra.xlsx")
profile = ProfileReport(df, title="Reporte EDA_Plato'sPizza", explorative=True)
profile.to_notebook_iframe()  # Muestra el reporte directamente en Google Colab
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# guarda el reporte como un archivo HTML
profile.to_file("reporte.html")

# descarga el archivo HTML (en la carpeta de descarga de la compu)
from google.colab import files
files.download("reporte.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
